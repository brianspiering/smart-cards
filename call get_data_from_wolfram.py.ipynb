# %% [markdown]
# TODO: Make flashcards for these: <br>
# http://www.mathwords.com/index_trig.htm

# %%
reset -fs

# %%
# %run get_data_from_wolfram.py
# Out:
# Enter a topic to query on Wolfram Alpha: distance formula
# Wolfram Alpha data stored for: distance formula

# %%
pod.attrs['title'].lower().strip()
# Out:
# 'visual form'
