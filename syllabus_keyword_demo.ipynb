# %%
reset -fs

# %%
import warnings
warnings.filterwarnings('ignore')
from IPython.display import Image

# %% [markdown]
# #SmartCards 2.0

# %%
Image(filename="data/images/temp.png")

# %%
# %run parse_syllabus.py
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# /Users/bfetters/projects/github/hacking_edu/parse_syllabus.py in <module>()
#      70         syllabus_text = f.read()
#      71
# ---> 72     terms = parse_syllabus(syllabus_text)
#      73
#      74
#
# /Users/bfetters/projects/github/hacking_edu/parse_syllabus.py in parse_syllabus(syllabus_text)
#      27
#      28     # get math lexicons
# ---> 29     df_cal = pd.read_csv("/Users/Alexander/hacking_edu/data/calculus_lexicon.csv", header=None)
#      30     df_alg = pd.read_csv("/Users/Alexander/hacking_edu/data/algebra_lexicon.csv", header=None)
#      31     df_trig = pd.read_csv("/Users/Alexander/hacking_edu/data/trigonometry_lexicon.csv", header=None)
#
# ...

# %%
for term in terms:
    print(term)
# Out:
# angles
# bound
# circular
# degree
# equations
# functions
# identities
# measure
# radian
# right
# triangles
# trig
# trigonometry
